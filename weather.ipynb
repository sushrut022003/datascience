# %% [markdown]
# <a href="https://colab.research.google.com/github/sushrut022003/datascience/blob/main/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('/content/weather_description.csv')

# %%
data
# Out:
#                  datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0     2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1     2012-10-01 13:00:00        0.0       0.0          150.0      0.0
# 2     2012-10-01 14:00:00        6.0       4.0          147.0      2.0
# 3     2012-10-01 15:00:00       20.0      18.0          141.0     10.0
# 4     2012-10-01 16:00:00       34.0      31.0          135.0     17.0
# ...                   ...        ...       ...            ...      ...
# 9416  2013-10-28 20:00:00        8.0      53.0          267.0     12.0
# 9417  2013-10-28 21:00:00      167.0      57.0          272.0     12.0
# 9418  2013-10-28 22:00:00      107.0      57.0          258.0      4.0
# 9419  2013-10-28 23:00:00      211.0      59.0          258.0      2.0
# 9420  2013-10-29 00:00:00      161.0      66.0          256.0     15.0
#
#       Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
data.head()
# Out:
#               datetime      Vancouver          Portland San Francisco  \
# 0  2012-10-01 12:00:00            NaN               NaN           NaN
# 1  2012-10-01 13:00:00           mist  scattered clouds    light rain
# 2  2012-10-01 14:00:00  broken clouds  scattered clouds  sky is clear
# 3  2012-10-01 15:00:00  broken clouds  scattered clouds  sky is clear
# 4  2012-10-01 16:00:00  broken clouds  scattered clouds  sky is clear
#
#         Seattle   Los Angeles     San Diego     Las Vegas       Phoenix  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  sky is clear          mist  sky is clear  sky is clear  sky is clear
# 2  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 3  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 4  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
#
#     Albuquerque  ...   Philadelphia    New York         Montreal  \
# ...

# %%
data.tail()
# Out:
#                  datetime             Vancouver       Portland  \
# 8552  2013-09-22 20:00:00  heavy intensity rain  moderate rain
# 8553  2013-09-22 21:00:00                  mist     light rain
# 8554  2013-09-22 22:00:00            light rain           mist
# 8555  2013-09-22 23:00:00            light rain  moderate rain
# 8556  2013-09-23 00:00:00         broken clouds  broken clouds
#
#          San Francisco               Seattle   Los Angeles     San Diego  \
# 8552      sky is clear         moderate rain  sky is clear    few clouds
# 8553      sky is clear       overcast clouds  sky is clear  sky is clear
# 8554      sky is clear         broken clouds  sky is clear  sky is clear
# 8555     broken clouds  heavy intensity rain  sky is clear  sky is clear
# 8556  scattered clouds         broken clouds  sky is clear  sky is clear
#
#          Las Vegas       Phoenix                   Albuquerque  ...  \
# 8552  sky is clear  sky is clear                  sky is clear  ...
# ...

# %%
data.describe()
# Out:
#                    datetime     Vancouver      Portland San Francisco  \
# count                  8557          8556          8556          8556
# unique                 8557            21            18            21
# top     2012-10-01 12:00:00  sky is clear  sky is clear          mist
# freq                      1          2874          2428          2069
#
#              Seattle   Los Angeles     San Diego     Las Vegas       Phoenix  \
# count           8556          8556          8556          8556          8556
# unique            16            18            16            16            20
# top     sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# freq            2377          4861          2681          6515          4945
#
#          Albuquerque  ...  Philadelphia      New York      Montreal  \
# count           8556  ...          8555          8555          8555
# unique            29  ...            22            26            30
# ...

# %%
data.shape
# Out:
# (8557, 37)

# %%
data.columns
# Out:
# Index(['datetime', 'Vancouver', 'Portland', 'San Francisco', 'Seattle',
#        'Los Angeles', 'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque',
#        'Denver', 'San Antonio', 'Dallas', 'Houston', 'Kansas City',
#        'Minneapolis', 'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis',
#        'Atlanta', 'Detroit', 'Jacksonville', 'Charlotte', 'Miami',
#        'Pittsburgh', 'Toronto', 'Philadelphia', 'New York', 'Montreal',
#        'Boston', 'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa',
#        'Nahariyya', 'Jerusalem'],
#       dtype='object')

# %%
data.dtypes
# Out:
# datetime             object
# Vancouver            object
# Portland             object
# San Francisco        object
# Seattle              object
# Los Angeles          object
# San Diego            object
# Las Vegas            object
# Phoenix              object
# Albuquerque          object
# Denver               object
# San Antonio          object
# Dallas               object
# Houston              object
# Kansas City          object
# Minneapolis          object
# Saint Louis          object
# Chicago              object
# Nashville            object
# Indianapolis         object
# Atlanta              object
# Detroit              object
# Jacksonville         object
# Charlotte            object
# Miami                object
# Pittsburgh           object
# Toronto              object
# Philadelphia         object
# New York             object
# Montreal             object
# Boston               object
# Beersheba            object
# Tel Aviv District    object
# ...

# %%
data['Portland'].unique()
# Out:
# array([nan, 'scattered clouds', 'sky is clear', 'few clouds',
#        'broken clouds', 'overcast clouds', 'mist', 'haze', 'dust', 'fog',
#        'moderate rain', 'light rain', 'heavy intensity rain',
#        'light intensity drizzle', 'heavy snow', 'snow', 'light snow',
#        'very heavy rain', 'thunderstorm'], dtype=object)

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of                  datetime             Vancouver          Portland  \
# 0     2012-10-01 12:00:00                   NaN               NaN
# 1     2012-10-01 13:00:00                  mist  scattered clouds
# 2     2012-10-01 14:00:00         broken clouds  scattered clouds
# 3     2012-10-01 15:00:00         broken clouds  scattered clouds
# 4     2012-10-01 16:00:00         broken clouds  scattered clouds
# ...                   ...                   ...               ...
# 8552  2013-09-22 20:00:00  heavy intensity rain     moderate rain
# 8553  2013-09-22 21:00:00                  mist        light rain
# 8554  2013-09-22 22:00:00            light rain              mist
# 8555  2013-09-22 23:00:00            light rain     moderate rain
# 8556  2013-09-23 00:00:00         broken clouds     broken clouds
#
#          San Francisco               Seattle   Los Angeles     San Diego  \
# ...

# %%
data.isnull()
# Out:
#       datetime  Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# 0        False       True      True           True     True         True
# 1        False      False     False          False    False        False
# 2        False      False     False          False    False        False
# 3        False      False     False          False    False        False
# 4        False      False     False          False    False        False
# ...        ...        ...       ...            ...      ...          ...
# 8552     False      False     False          False    False        False
# 8553     False      False     False          False    False        False
# 8554     False      False     False          False    False        False
# 8555     False      False     False          False    False        False
# 8556     False      False     False          False    False        False
#
#       San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  New York  \
# ...

# %%
data.isnull().sum()
# Out:
# datetime             0
# Vancouver            1
# Portland             1
# San Francisco        1
# Seattle              1
# Los Angeles          1
# San Diego            1
# Las Vegas            1
# Phoenix              1
# Albuquerque          1
# Denver               1
# San Antonio          1
# Dallas               2
# Houston              2
# Kansas City          2
# Minneapolis          2
# Saint Louis          2
# Chicago              2
# Nashville            2
# Indianapolis         2
# Atlanta              2
# Detroit              2
# Jacksonville         2
# Charlotte            2
# Miami                2
# Pittsburgh           2
# Toronto              2
# Philadelphia         2
# New York             2
# Montreal             2
# Boston               2
# Beersheba            2
# Tel Aviv District    2
# Eilat                1
# Haifa                2
# Nahariyya            2
# Jerusalem            2
# dtype: int64

# %%
data.rename(columns={"Hafia":"Hafia Condition"})
# Out:
#                  datetime             Vancouver          Portland  \
# 0     2012-10-01 12:00:00                   NaN               NaN
# 1     2012-10-01 13:00:00                  mist  scattered clouds
# 2     2012-10-01 14:00:00         broken clouds  scattered clouds
# 3     2012-10-01 15:00:00         broken clouds  scattered clouds
# 4     2012-10-01 16:00:00         broken clouds  scattered clouds
# ...                   ...                   ...               ...
# 8552  2013-09-22 20:00:00  heavy intensity rain     moderate rain
# 8553  2013-09-22 21:00:00                  mist        light rain
# 8554  2013-09-22 22:00:00            light rain              mist
# 8555  2013-09-22 23:00:00            light rain     moderate rain
# 8556  2013-09-23 00:00:00         broken clouds     broken clouds
#
#          San Francisco               Seattle   Los Angeles     San Diego  \
# 0                  NaN                   NaN           NaN           NaN
# ...

# %%
data=pd.read_csv('/content/humidity.csv')

# %%
data['Portland'].mean()
# Out:
# 75.84935483870967

# %%
data['Las Vegas'].median()
# Out:
# 24.0

# %%
data['Boston'].std()
# Out:
# 18.823479361834206

# %%
data['Chicago'].value_counts()
# Out:
# 89.0     1318
# 100.0     500
# 93.0      474
# 74.0      443
# 87.0      392
#          ...
# 6.0         1
# 10.0        1
# 21.0        1
# 13.0        1
# 9.0         1
# Name: Chicago, Length: 91, dtype: int64

# %%
data[data['Boston']==68]
# Out:
#                   datetime  Vancouver  Portland  San Francisco  Seattle  \
# 1      2012-10-01 13:00:00       76.0      81.0           88.0     81.0
# 2      2012-10-01 14:00:00       76.0      80.0           87.0     80.0
# 3      2012-10-01 15:00:00       76.0      80.0           86.0     80.0
# 4      2012-10-01 16:00:00       77.0      80.0           85.0     79.0
# 5      2012-10-01 17:00:00       78.0      79.0           84.0     79.0
# ...                    ...        ...       ...            ...      ...
# 15778  2014-07-20 22:00:00       68.0      52.0           60.0     55.0
# 15779  2014-07-20 23:00:00       68.0      49.0           60.0     59.0
# 15794  2014-07-21 14:00:00       77.0      87.0           77.0     93.0
# 15829  2014-07-23 01:00:00       64.0      64.0           64.0     56.0
# 15913  2014-07-26 13:00:00       87.0      87.0           87.0     93.0
#
#        Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
data['Nashville']>90
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 15945    False
# 15946    False
# 15947    False
# 15948    False
# 15949    False
# Name: Nashville, Length: 15950, dtype: bool

# %%
data.groupby("Nashville").mean()
# Out:
#            Vancouver   Portland  San Francisco    Seattle  Los Angeles  \
# Nashville
# 10.0       71.000000  61.000000      74.000000  56.000000    24.000000
# 12.0       65.000000  70.000000      55.000000  81.000000    27.000000
# 13.0       47.000000  72.000000      82.000000  35.500000    47.000000
# 14.0       87.000000  50.000000      87.000000  54.000000    77.000000
# 15.0       74.750000  58.400000      73.400000  68.800000    50.200000
# ...              ...        ...            ...        ...          ...
# 96.0       82.855263  81.025974      78.120000  78.662338    67.805195
# 97.0       81.376812  82.605634      77.478873  80.450704    65.957746
# 98.0       83.866667  78.344262      78.672131  79.327869    60.016393
# 99.0       79.184713  77.422360      80.901235  74.123457    70.565217
# 100.0      83.357430  82.537849      75.244186  79.062992    66.286822
#
#            San Diego  Las Vegas    Phoenix  Albuquerque     Denver  ...  \
# ...

# %%
data.groupby("Nashville").min()
# Out:
#                       datetime  Vancouver  Portland  San Francisco  Seattle  \
# Nashville
# 10.0       2013-11-11 21:00:00       71.0      61.0           74.0     56.0
# 12.0       2014-02-21 22:00:00       65.0      70.0           55.0     81.0
# 13.0       2013-11-11 20:00:00       23.0      62.0           81.0     14.0
# 14.0       2014-02-28 21:00:00       87.0      50.0           87.0     54.0
# 15.0       2014-02-21 21:00:00       60.0      47.0           67.0     50.0
# ...                        ...        ...       ...            ...      ...
# 96.0       2012-10-02 01:00:00       46.0      40.0           36.0     36.0
# 97.0       2012-10-01 21:00:00       53.0      38.0           26.0     37.0
# 98.0       2012-10-01 18:00:00       45.0      39.0           28.0     40.0
# 99.0       2012-10-01 14:00:00       27.0      33.0           43.0     31.0
# 100.0      2012-10-01 13:00:00       26.0      32.0           15.0     32.0
#
# ...

# %%
data.groupby("Nashville").max().head()
# Out:
#                       datetime  Vancouver  Portland  San Francisco  Seattle  \
# Nashville
# 10.0       2013-11-11 21:00:00       71.0      61.0           74.0     56.0
# 12.0       2014-02-21 22:00:00       65.0      70.0           55.0     81.0
# 13.0       2014-04-20 15:00:00       71.0      82.0           83.0     57.0
# 14.0       2014-02-28 21:00:00       87.0      50.0           87.0     54.0
# 15.0       2014-02-28 22:00:00       87.0      70.0           82.0     86.0
#
#            Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# Nashville                                                           ...
# 10.0              24.0       28.0       17.0     14.0         26.0  ...
# 12.0              27.0       33.0       10.0      9.0         10.0  ...
# 13.0              73.0       30.0       35.0     43.0         26.0  ...
# 14.0              77.0       88.0       67.0     22.0         20.0  ...
# ...

# %%
data[data['Miami']==79]
# Out:
#                   datetime  Vancouver  Portland  San Francisco  Seattle  \
# 10     2012-10-01 22:00:00       81.0      77.0           79.0     76.0
# 11     2012-10-01 23:00:00       81.0      77.0           78.0     75.0
# 12     2012-10-02 00:00:00       82.0      76.0           77.0     75.0
# 74     2012-10-04 14:00:00       40.0      74.0           72.0     59.0
# 86     2012-10-05 02:00:00       46.0      25.0           68.0     44.0
# ...                    ...        ...       ...            ...      ...
# 15827  2014-07-22 23:00:00       77.0      60.0           79.0     69.0
# 15874  2014-07-24 22:00:00       88.0      91.0           61.0     83.0
# 15877  2014-07-25 01:00:00       68.0      85.0           59.0     74.0
# 15912  2014-07-26 12:00:00       87.0      92.0           98.0     93.0
# 15914  2014-07-26 14:00:00       82.0      82.0           82.0     93.0
#
#        Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
data=pd.read_csv('/content/pressure.csv')

# %%
data['San Diego'].mean()
# Out:
# 1017.2153885743695

# %%
data['Albuquerque'].median()
# Out:
# 1017.0

# %%
data.columns
# Out:
# Index(['datetime', 'Vancouver', 'Portland', 'San Francisco', 'Seattle',
#        'Los Angeles', 'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque',
#        'Denver', 'San Antonio', 'Dallas', 'Houston', 'Kansas City',
#        'Minneapolis', 'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis',
#        'Atlanta', 'Detroit', 'Jacksonville', 'Charlotte', 'Miami',
#        'Pittsburgh', 'Toronto', 'Philadelphia', 'New York', 'Montreal',
#        'Boston', 'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa',
#        'Nahariyya', 'Jerusalem'],
#       dtype='object')

# %%
data['Houston'].var()
# Out:
# 46.112629322316955

# %%
data=pd.read_csv('/content/wind_direction.csv')

# %%
data['Houston'].mean()
# Out:
# 150.80095541401275

# %%
data['Albuquerque'].value_counts()
# Out:
# 0.0      986
# 340.0    241
# 360.0    237
# 330.0    229
# 10.0     189
#         ...
# 58.0       2
# 12.0       2
# 23.0       1
# 308.0      1
# 31.0       1
# Name: Albuquerque, Length: 360, dtype: int64

# %%
len(data[(data.Albuquerque=='Clear')])
# Out:
# 0

# %%
data['Charlotte'].unique()
# Out:
# array([ nan,  70.,  71.,  72.,  73.,  74.,  75.,  76.,  77.,  78.,  79.,
#         80.,  81.,  82.,  83.,  84.,  85.,  86.,  87.,  88.,  89.,  90.,
#          0.,  60.,  50., 100., 110., 120., 130., 150., 160., 170., 113.,
#         56., 180., 210., 220., 230., 225., 280., 200., 260., 290., 340.,
#        350., 270., 330., 165.,  20., 190.,  66., 133.,  10.,  40.,  30.,
#         45., 360.,  16.,  23., 316., 153., 306., 125., 250., 240., 263.,
#        266., 269., 272., 320., 310., 140., 300., 201., 172., 143., 115.,
#         57.,  28., 227., 102., 191., 111.,  32., 277.,  15.,  53.,  55.,
#         22.,  31., 185., 131., 176., 156., 159.,  29.,  52.,  35.,  42.,
#         25., 154.,  36., 181., 326., 135.,  99., 199., 357.,   6.,  43.,
